# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
from ultralytics import settings

# Update a setting
settings.update({"runs_dir": "./runs"})
settings.update({"datasets_dir": "./"})
settings.update({"weights_dir": "./"})

# %%
# !yolo settings
# Out:
# 💡 Learn about settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings
# Printing '/Users/niklas/Library/Application Support/Ultralytics/settings.yaml'
#
# settings_version: 0.0.4
# datasets_dir: ./
# weights_dir: /Users/niklas/coin-counter/weights
# runs_dir: ./runs
# uuid: d6dc5273eb014d0a5d754cdbf0f60bb0fa8ec8d0972aa51a3644769e377fd716
# sync: true
# api_key: ''
# openai_api_key: ''
# clearml: true
# comet: true
# dvc: true
# hub: true
# mlflow: true
# neptune: true
# raytune: true
# tensorboard: true
# wandb: true

# %%
results = model.train(data="./data.yaml", epochs=1, imgsz=323, device="mps")
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.12.3 torch-2.3.1 MPS (Apple M2)
# ...

# %%
results = model("./org_data/images/test/image00002_rot.jpg")
# Out:
# image 1/1 /Users/niklas/coin-counter/org_data/images/test/image00002_rot.jpg: 352x352 1 5, 320.6ms
# Speed: 196.0ms preprocess, 320.6ms inference, 2548.7ms postprocess per image at shape (1, 3, 352, 352)

# %%
annotated_image = results[0].plot()
import cv2
#from google.colab.patches import cv2_imshow
# Display the image using OpenCV
cv2.imshow("Image", annotated_image)
cv2.waitKey(0) 
  
# closing all open windows 
cv2.destroyAllWindows()

# %%
class_names = results[0].names
class_names

# %%
result = results[0]
class_names = result.names  # List of class names

# %%
for box in boxes:
    x1, y1, x2, y2 = box.xyxy[0].numpy()
    class_id = int(box.cls)
    score = box.conf[0].numpy()
    class_name = class_names[class_id]

    print(f"Class: {class_name}, Score: {score:.2f}, Box: [{x1:.2f}, {y1:.2f}, {x2:.2f}, {y2:.2f}]")

# %%
classes = model.names
for result in results:
    boxes = result.boxes.cpu().numpy()
    print(boxes.conf)
    class_ids= boxes.cls
    class_names = [classes[key] for key in class_ids]
    print(class_names)
    result.show()
